# %% [markdown]
# # Welcome to Gravitational Waves
#
# This is a placeholder notebook to confirm the JupyterHub + nbgitpuller setup is working.
#
# Run the cell below to check the environment.

# %%
import sys
print("Python", sys.version)
import numpy, scipy, matplotlib
print("numpy", numpy.__version__)
print("scipy", scipy.__version__)
print("matplotlib", matplotlib.__version__)
